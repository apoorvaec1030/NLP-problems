# %% [markdown]
# "
# We use autocorrect everyday in our phones, computers, emails etc. Lets look at what goes behind the scenes.
# Few concepts to note:
#
# 1. Bayes theorem: P(c|w)=P(w|c)xP(c)/P(w)
# 2. Minimum Edit Distance:
#     An edit could consist of following options:
#     insert - 1 edit distance
#     delete - 1 edit distance
#     replace - 1 insert + 1 del = 2 edit distance
#     switch - 1 del + 1 insert = 2 edit distance
# 3. Dynamic Programming method - faster method to perform autocorrect on longer text *we will talk about this later
#
# Data processing:
# 1. load string of data
# 2. Convert the string of text into words
# 3. calculate word freqs and then word prob
#
# String Manipulation options:
# 1. insert 1 character
# 2. delete 1 character
# 3. replace 1 character
# 4. switch 1 character
#
# Combining the edits:
# 1. edit one letter
# 2. edit two letter
# 3. spelling suggestions
#
# Minimum Edit Distance:
# 1. Dynamic programming
#
# "

# %%
import re
from collections import Counter
import numpy as np
import pandas as pd

# %% [markdown]
# ### Data Processing

# %%
#load txt file and process data to separate words
def load_process_data(file):
    with open(file) as f:
        data = f.read() #reads entire txt file in string
    
    data_lwr = data.lower()
    
    #separate every word and return a list
    words = re.findall('\w+',data_lwr) #\w is matching word character and + is for all the preceeding word characters, making an entire word
    
    return words

# %%
words_all = load_process_data('stringoftext.txt')
vocab = set(words_all) #this is our vocabulary

# %%
def get_freq(words_all):
    word_freq = {}
    word_freq = Counter(words_all)
    return word_freq

def get_prob(word_freq):
    prob = {}
    prob = {k:v/sum(word_freq.values()) for k,v in word_freq.items()}
    return prob

# %%
word_freq = get_freq(words_all)
print(word_freq)

prob = get_prob(word_freq)
print(prob)
# Out:
# Counter({'the': 6, 'economy': 3, 'globalization': 3, 'is': 3, 'many': 3, 'job': 3, 'outsourcing': 3, 'american': 2, 'while': 2, 'at': 2, 'nirma': 2, 'surma': 2, 'true': 2, 'an': 1, 'a': 1, 'very': 1, 'pressing': 1, 'issue': 1, 'in': 1, 'culture': 1, 'today': 1, 'within': 1, 'any': 1, 'will': 1, 'cause': 1, 'problems': 1, 'same': 1, 'time': 1, 'solving': 1, 'others': 1, 'this': 1, 'because': 1, 'there': 1, 'are': 1, 'factors': 1, 'involved': 1, 'with': 1, 'one': 1, 'of': 1, 'most': 1, 'important': 1, 'being': 1, 'first': 1, 'glance': 1, 'and': 1, 'from': 1, 'what': 1, 'media': 1, 'reports': 1, 'definitely': 1, 'not': 1, 'healthy': 1, 'for': 1, 'however': 1, 'on': 1, 'upon': 1, 'closer': 1, 'inspection': 1, 'reverse': 1, 'may': 1, 'be': 1, 'karma': 1})
# {'an': 0.011764705882352941, 'american': 0.023529411764705882, 'economy': 0.03529411764705882, 'globalization': 0.03529411764705882, 'is': 0.03529411764705882, 'a': 0.011764705882352941, 'very': 0.011764705882352941, 'pressing': 0.011764705882352941, 'issue': 0.011764705882352941, 'in': 0.011764705882352941, 'the': 0.07058823529411765, 'culture': 0.011764705882352941, 'today': 0.011764705882352941, 'within': 0.011764705882352941, 'any': 0.011764705882352941, 'will': 0.011764705882352941, 'cause': 0.011764705882352941, 'many': 0.03529411764705882, 'problems': 0.011764705882352941, 'while': 0.023529411764705882, 'at': 0.023529411764705882, 'same': 0.011764705882352941, 'nirma': 0.023529411764705882, 'time': 0.011764705882352941, 'solving': 0.011764705882352941, 'surma': 0.023529411764705882, 'others': 0.011764705882352941, 'this': 0.011764705882352941, 'true': 0.023529411764705882, 'because': 0.011764705882352941, 'there': 0.011764705882352941, 'are': 0.011764705882352941, 'factors': 0.011764705882352941, 'involved': 0.011764705882352941, 'with': 0.011764705882352941, 'one': 0.011764705882352941, 'of': 0.011764705882352941, 'most': 0.011764705882352941, 'important': 0.011764705882352941, 'being': 0.011764705882352941, 'job': 0.03529411764705882, 'outsourcing': 0.03529411764705882, 'first': 0.011764705882352941, 'glance': 0.011764705882352941, 'and': 0.011764705882352941, 'from': 0.011764705882352941, 'what': 0.011764705882352941, 'media': 0.011764705882352941, 'reports': 0.011764705882352941, 'definitely': 0.011764705882352941, 'not': 0.011764705882352941, 'healthy': 0.011764705882352941, 'for': 0.011764705882352941, 'however': 0.011764705882352941, 'on': 0.011764705882352941, 'upon': 0.011764705882352941, 'closer': 0.011764705882352941, 'inspection': 0.011764705882352941, 'reverse': 0.011764705882352941, 'may': 0.011764705882352941, 'be': 0.011764705882352941, 'karma': 0.011764705882352941}

# %% [markdown]
# ### String Manipulation Options

# %%
def delete_char(word):
    '''1. Split word 1 letter at a time; 
       2. Delete the last char of left split'''

    split_l = [(word[:i],word[i:]) for i in range(len(word))]
    delete_l = [L[:-1]+R for L,R in split_l[1:]]
    return delete_l

def insert_char(word):
    '''1. Split word 1 letter at a time; 
       2. Insert between L&R split'''
    letter = 'abcdefghijklmnopqrstuvwxyz'
    
    split_l = [(word[:i],word[i:]) for i in range(len(word))]
    insert_l = [L+i+R for L,R in split_l for i in letter]
    return insert_l
    
def replace_char(word):
    '''1. Split word 1 letter at a time; 
       2. Skip the first char of right split and
       3. Insert between L&R split'''
    
    letter = 'abcdefghijklmnopqrstuvwxyz'
    
    split_l = [(word[:i],word[i:]) for i in range(len(word))]
    replace_l = [L+i+R[1:] for L,R in split_l for i in letter]
    
    return replace_l

def switch_char(word):
    '''1. Split word 1 letter at a time; 
       2. swap the first two chars of R, given len(word)>=2'''
    
    split_l = [(word[:i],word[i:]) for i in range(len(word))]
    switch_l = [L+R[1]+R[0]+R[2:] for L,R in split_l if len(R)>=2]
    
    return switch_l

# %% [markdown]
# ### One Letter Edit

# %%
def one_edit(word, switch_plug = True):
    '''
    1. run all the string manipulations
    2. combine all the unique outputs that are one edit away
    3. switch is optional, not that common
    '''
    
    delete = delete_char(word)
    insert = insert_char(word)
    replace = replace_char(word)

    
    switch = []
    if switch_plug:
        switch = switch_char(word)
    
    one_edit_char = delete+insert+replace+switch
    
    return set(one_edit_char)

# %%
one_edit('kama')
# Out:
# {'aama',
#  'akama',
#  'akma',
#  'ama',
#  'bama',
#  'bkama',
#  'cama',
#  'ckama',
#  'dama',
#  'dkama',
#  'eama',
#  'ekama',
#  'fama',
#  'fkama',
#  'gama',
#  'gkama',
#  'hama',
#  'hkama',
#  'iama',
#  'ikama',
#  'jama',
#  'jkama',
#  'kaa',
#  'kaaa',
#  'kaam',
#  'kaama',
#  'kaba',
#  'kabma',
#  'kaca',
#  'kacma',
#  'kada',
#  'kadma',
#  'kaea',
#  'kaema',
#  'kafa',
#  'kafma',
#  'kaga',
#  'kagma',
#  'kaha',
#  'kahma',
#  'kaia',
#  'kaima',
#  'kaja',
#  'kajma',
#  'kaka',
#  'kakma',
#  'kala',
#  'kalma',
#  'kama',
#  'kamaa',
#  'kamb',
#  'kamba',
#  'kamc',
#  'kamca',
#  'kamd',
#  'kamda',
#  'kame',
#  'kamea',
#  'kamf',
#  'kamfa',
#  'kamg',
#  'kamga',
#  'kamh',
#  'kamha',
#  'kami',
#  'kamia',
#  'kamj',
#  'kamja',
#  'kamk',
#  'kamka',
#  'kaml',
#  'kamla',
#  'kamm',
#  'kamma',
#  'kamn',
#  'kamna',
#  'kamo',
#  'kamoa',
#  'kamp',
#  'kampa',
#  'kamq',
#  'kamqa',
#  'kamr',
#  'kamra',
#  'kams',
#  'kamsa',
#  'kamt',
#  'kamta',
#  'kamu',
#  'kamua',
#  'kamv',
#  'kamva',
#  'kamw',
#  'kamwa',
#  'kamx',
#  'kamxa',
#  'kamy',
#  'kamya',
#  'kamz',
#  'kamza',
#  'kana',
#  'kanma',
#  'kaoa',
#  'kaoma',
#  'kapa',
#  'kapma',
#  'kaqa',
#  'kaqma',
#  'kara',
#  'karma',
#  'kasa',
#  'kasma',
#  'kata',
#  'katma',
#  'kaua',
#  'kauma',
#  'kava',
#  'kavma',
#  'kawa',
#  'kawma',
#  'kaxa',
#  'kaxma',
#  'kaya',
#  'kayma',
#  'kaza',
#  'kazma',
#  'kbama',
#  'kbma',
#  'kcama',
#  'kcma',
#  'kdama',
#  'kdma',
#  'keama',
#  'kema',
#  'kfama',
#  'kfma',
#  'kgama',
#  'kgma',
#  'khama',
#  'khma',
#  'kiama',
#  'kima',
#  'kjama',
#  'kjma',
#  'kkama',
#  'kkma',
#  'klama',
#  'klma',
#  'kma',
#  'kmaa',
#  'kmama',
#  'kmma',
#  'knama',
#  'knma',
#  'koama',
#  'koma',
#  'kpama',
#  'kpma',
#  'kqama',
#  'kqma',
#  'krama',
#  'krma',
#  'ksama',
#  'ksma',
#  'ktama',
#  'ktma',
#  'kuama',
#  'kuma',
#  'kvama',
#  'kvma',
#  'kwama',
#  'kwma',
#  'kxama',
#  'kxma',
#  'kyama',
#  'kyma',
#  'kzama',
#  'kzma',
#  'lama',
#  'lkama',
#  'mama',
#  'mkama',
#  'nama',
#  'nkama',
#  'oama',
#  'okama',
#  'pama',
#  'pkama',
#  'qama',
#  'qkama',
#  'rama',
#  'rkama',
#  'sama',
#  'skama',
#  'tama',
#  'tkama',
#  'uama',
#  'ukama',
#  'vama',
#  'vkama',
#  'wama',
#  'wkama',
#  'xama',
#  'xkama',
#  'yama',
#  'ykama',
#  'zama',
#  'zkama'}

# %%
def two_edit(word, switch_plug = True):
    '''
    1. run one_edit 
    2. run it again on the previous output
    '''
    
    one_edit_words = one_edit(word, switch_plug=False)

    two_edit_words=set()
    for letter in one_edit_words:
        if letter:
            two_edit = one_edit(letter, switch_plug=False) 
            two_edit_words.update(two_edit)

    return two_edit_words

# %%
two_edit('ameican')
# Out:
# {'ameimckan',
#  'asmweican',
#  'ameivman',
#  'lmeicxn',
#  'ahmeicav',
#  'vmeicax',
#  'kamelcan',
#  'imegican',
#  'lmeicwn',
#  'aaeicah',
#  'almlican',
#  'hrmeican',
#  'apeicax',
#  'almeocan',
#  'uameicman',
#  'ameicar',
#  'amxgican',
#  'umeizan',
#  'acmeicay',
#  'amelcamn',
#  'ameicwayn',
#  'akeictan',
#  'ameicahm',
#  'amekiucan',
#  'ameiccavn',
#  'mmeicay',
#  'amebixan',
#  'amuseican',
#  'ameincaan',
#  'ameryan',
#  'zmneican',
#  'amician',
#  'gameicak',
#  'rsmeican',
#  'amleicag',
#  'pmeilan',
#  'abeiyan',
#  'awmeitcan',
#  'tamexican',
#  'ameicayr',
#  'amefcman',
#  'ameibtn',
#  'afmeicah',
#  'ameijqcan',
#  'axmeycan',
#  'admaican',
#  'arekican',
#  'amescdn',
#  'amegicajn',
#  'ameokan',
#  'amenicpn',
#  'nmeccan',
#  'aieicwn',
#  'avmeicean',
#  'abmyican',
#  'aquican',
#  'ameicaua',
#  'aomeicon',
#  'auewcan',
#  'ateicagn',
#  'ameizcai',
#  'amficsan',
#  'vomeican',
#  'aymeicac',
#  'lameacan',
#  'dmetican',
#  'ameijun',
#  'reeican',
#  'ammescan',
#  'bameicazn',
#  'kameimcan',
#  'jajeican',
#  'amezicaln',
#  'aymeicap',
#  'jameoican',
#  'gameicon',
#  'amicad',
#  'oameicacn',
#  'pameicwn',
#  'ameigpan',
#  'amlfcan',
#  'amfeigan',
#  'gameiycan',
#  'andican',
#  'anfeican',
#  'amlicyn',
#  'ameicayvn',
#  'jampican',
#  'pmeicaa',
#  'amebicean',
#  'cameihan',
#  'amelcian',
#  'qamjeican',
#  'amoeiean',
#  'amewdan',
#  'aveijan',
#  'amaiian',
#  'ameicmfan',
#  'ahekican',
#  'ajmeicun',
#  'ajeicyn',
#  'armeecan',
#  'acmetican',
#  'americawn',
#  'aymegican',
#  'yaieican',
#  'ameimcayn',
#  'qmeickn',
#  'amsevican',
#  'amejcaan',
#  'zameilan',
#  'smzican',
#  'ampicfan',
#  'ameacapn',
#  'amequan',
#  'anrmeican',
#  'ameicoajn',
#  'amecicaon',
#  'mameizcan',
#  'udeican',
#  'azmeictn',
#  'aqeinan',
#  'amyjeican',
#  'amlicnn',
#  'hmeihan',
#  'ameizcln',
#  'ameiuqn',
#  'ameibmn',
#  'hmican',
#  'ameickayn',
#  'emencan',
#  'amevuan',
#  'amegcaun',
#  'xmeicazn',
#  'ameiqxan',
#  'aueictn',
#  'pamvican',
#  'ameicoh',
#  'aimeqican',
#  'ameickoan',
#  'amkivan',
#  'qameicarn',
#  'mameiyan',
#  'ameimann',
#  'amxewican',
#  'afumeican',
#  'aomeicaf',
#  'amebicafn',
#  'amneiwan',
#  'aeeicaq',
#  'ametidcan',
#  'meicgn',
#  'ameicaabn',
#  'namfican',
#  'vdmeican',
#  'aymeocan',
#  'ameifcvn',
#  'ameicrb',
#  'amweeican',
#  'ameeiwcan',
#  'ameticfan',
#  'ateisan',
#  'akpeican',
#  'rameircan',
#  'amewicaqn',
#  'amrwcan',
#  'sameicajn',
#  'ameicpajn',
#  'ameiccain',
#  'apelcan',
#  'umenican',
#  'smqican',
#  'amtocan',
#  'hamencan',
#  'vmuican',
#  'amhickn',
#  'amexicaa',
#  'amebicfan',
#  'ymepican',
#  'ameidqn',
#  'amelcap',
#  'kmeicagn',
#  'amekbican',
#  'umeicdan',
#  'ampeqcan',
#  'ameicjkan',
#  'apmeiccn',
#  'izeican',
#  'cmheican',
#  'aieipan',
#  'amemicaxn',
#  'amenicax',
#  'kxeican',
#  'areiwan',
#  'dameigcan',
#  'amcicaan',
#  'sdameican',
#  'amicxan',
#  'ameldcan',
#  'ameicya',
#  'amelcam',
#  'amaezican',
#  'ameicmsn',
#  'ameicafp',
#  'admeichn',
#  'ambeiean',
#  'afgmeican',
#  'qmeidcan',
#  'agdmeican',
#  'vmxican',
#  'ameijcun',
#  'ammqican',
#  'amueicon',
#  'avmjican',
#  'oemeican',
#  'aopmeican',
#  'aleiaan',
#  'ameinycan',
#  'ameckcan',
#  'mmeicasn',
#  'amxeicaln',
#  'amreicav',
#  'auecican',
#  'ameydan',
#  'aymeicwan',
#  'aeimeican',
#  'ameccfan',
#  'ameaicar',
#  'ameiyhn',
#  'amseoican',
#  'fmeicqn',
#  'ammidcan',
#  'qmefcan',
#  'ameiwycan',
#  'afeicaon',
#  'ameucaj',
#  'ateuican',
#  'namveican',
#  'ameilap',
#  'ahmyican',
#  'lamzeican',
#  'amoeicwan',
#  'ameziuan',
#  'amzicatn',
#  'ageichn',
#  'ameicdaln',
#  'tameifan',
#  'amouican',
#  'amnicac',
#  'bamneican',
#  'aleicsan',
#  'amteacan',
#  'namzeican',
#  'mmeigan',
#  'americran',
#  'ameirpcan',
#  'ameiycran',
#  'aqmeikcan',
#  'amricaj',
#  'eaceican',
#  'amexicwan',
#  'afeucan',
#  'ameiycawn',
#  'ahmoican',
#  'amsdcan',
#  'amqeican',
#  'aeicahn',
#  'jbmeican',
#  'frameican',
#  'akpican',
#  'ameitcin',
#  'afmeicaq',
#  'amesicyan',
#  'ameicwn',
#  'pameivan',
#  'imican',
#  'ewmeican',
#  'ameifarn',
#  'namefican',
#  'amecicaxn',
#  'eyameican',
#  'vapmeican',
#  'aymehican',
#  'ameicqar',
#  'ampicaz',
#  'ameizban',
#  'ameicgatn',
#  'ametcag',
#  'amemzan',
#  'amueicaq',
#  'iemeican',
#  'ameidczn',
#  'amkeicaln',
#  'ameiqcan',
#  'ameimczn',
#  'amdicax',
#  'amweicun',
#  'aemeicean',
#  'aseiycan',
#  'aweician',
#  'axescan',
#  'ayeqcan',
#  'ayeicqn',
#  'ameicnxan',
#  'amelizcan',
#  'wmeicacn',
#  'amelicau',
#  'aumeicab',
#  'kmeicaqn',
#  'vameicah',
#  'iameicakn',
#  'amgpican',
#  'amelcfan',
#  'ameijcoan',
#  'amkecican',
#  'ameijmcan',
#  'amkicaa',
#  'gmeiman',
#  'amqezcan',
#  'armeicak',
#  'amgicon',
#  'amaeicay',
#  'ateicaun',
#  'wmedcan',
#  'ameidbcan',
#  'amuqican',
#  'hmrican',
#  'apmeicao',
#  'ameoicaan',
#  'aegcan',
#  'vmeicap',
#  'ameixkan',
#  'ametkican',
#  'aumeidcan',
#  'amicqan',
#  'ameidqan',
#  'pameiycan',
#  'atmeifcan',
#  'qmueican',
#  'ammesican',
#  'ameiichan',
#  'armeibcan',
#  'aoeicean',
#  'amenctn',
#  'amgeiclan',
#  'amxeidan',
#  'aleiccn',
#  'cmeiran',
#  'fmeicaan',
#  'amaeicsan',
#  'ameixcban',
#  'ayzmeican',
#  'ameqcpn',
#  'hmeicaq',
#  'ameiefcan',
#  'rwmeican',
#  'ateicawn',
#  'amdeicamn',
#  'ameciyan',
#  'ameicwg',
#  'nafeican',
#  'yameicafn',
#  'mameccan',
#  'amfepcan',
#  'kameivcan',
#  'amecax',
#  'azmecican',
#  'amelircan',
#  'ameicon',
#  'aoedican',
#  'hmeiecan',
#  'amoicgn',
#  'amekcakn',
#  'abeinan',
#  'ymeicaan',
#  'kmeacan',
#  'ameqixcan',
#  'aeeical',
#  'amejcarn',
#  'aqueican',
#  'pajmeican',
#  'amieicwan',
#  'eameicay',
#  'uameiqcan',
#  'mmeinan',
#  'aveixcan',
#  'agmeicav',
#  'azmeicsn',
#  'kateican',
#  'ameictar',
#  'aojican',
#  'wmeimcan',
#  'gmetican',
#  'aceicgan',
#  'admeitan',
#  'ameimcam',
#  'ameipgan',
#  'ameicctan',
#  'ameaiacan',
#  'amzeicatn',
#  'ameticaz',
#  'amedcat',
#  'vameiaan',
#  'ambeicoan',
#  'amciecan',
#  'asmeikan',
#  'amwefican',
#  'ameticaen',
#  'aimeicasn',
#  'iameicat',
#  'ameixjan',
#  'amjefcan',
#  'amelnan',
#  'tameicah',
#  'amcicaq',
#  'dameicgn',
#  'avmeicman',
#  'xmeiczn',
#  'aeucan',
#  'asmedcan',
#  'ameircyan',
#  'aaeigcan',
#  'sameicmn',
#  'pamejican',
#  'awmeicayn',
#  'amzicn',
#  'aqmeicaen',
#  'ampeicam',
#  'vamzican',
#  'ameiocarn',
#  'dmweican',
#  'aumeicaqn',
#  'amehincan',
#  'mameicyan',
#  'ameiuwn',
#  'amejlcan',
#  'ameldan',
#  'anmeitcan',
#  'amsicean',
#  'ameskcan',
#  'aqmeicpn',
#  'ameicstn',
#  'ametigan',
#  'mameicqn',
#  'aedican',
#  'amehicar',
#  'nmeicakn',
#  'gameichn',
#  'ambeiwan',
#  'xamebcan',
#  'ameiebcan',
#  'ameicacd',
#  'samezcan',
#  'amkipcan',
#  'avzeican',
#  'ymiican',
#  'ameicaovn',
#  'yasmeican',
#  'aneiocan',
#  'amhizan',
#  'emzeican',
#  'rageican',
#  'amceicfn',
#  'zmican',
#  'aqeuican',
#  'amecin',
#  'lmeikcan',
#  'amheitan',
#  'ameicmv',
#  'ameicafh',
#  'pmeiqcan',
#  'uheican',
#  'smecan',
#  'ameijjn',
#  'amexxan',
#  'amreicah',
#  'amebicwn',
#  'amfeicaan',
#  'ameiqyn',
#  'gmeyican',
#  'admgeican',
#  'ameifocan',
#  'ameicfaqn',
#  'tjeican',
#  'lkeican',
#  'amuicjan',
#  'rmrican',
#  'ameqgican',
#  'amemcal',
#  'xmegcan',
#  'auaeican',
#  'amyeicdn',
#  'smeiocan',
#  'amenicaen',
#  'amzeiccn',
#  'ameekan',
#  'akmeicpan',
#  'smesican',
#  'amgeivcan',
#  'pmeichan',
#  'ameixcaon',
#  'ameriscan',
#  'amleicuan',
#  'ambeiscan',
#  'ahmeicaa',
#  'aqmeicat',
#  'aafmeican',
#  'ameibon',
#  'amedicmn',
#  'amgeiwcan',
#  'wacmeican',
#  'aweicat',
#  'amdqeican',
#  'ameoiccan',
#  'qambican',
#  'anmeikcan',
#  'amoeicafn',
#  'amhelican',
#  'ameiacban',
#  'amegicak',
#  'aqeacan',
#  'amdeicaxn',
#  'ameicartn',
#  'amehinan',
#  'ymeichan',
#  'ameoclan',
#  'amebcabn',
#  'hameilcan',
#  'ampeican',
#  'ametcan',
#  'amoicin',
#  'aymeicazn',
#  'aaeicgn',
#  'aadeican',
#  'ameickaqn',
#  'ambicsn',
#  'kmezcan',
#  'amneicax',
#  'ambecan',
#  'asmeicap',
#  'ameidckn',
#  'amlleican',
#  'amveicap',
#  'amreicao',
#  'amneiccan',
#  'xamaican',
#  'amciwan',
#  'qmemican',
#  'amteicaxn',
#  'aomeiran',
#  'amwicao',
#  'smpeican',
#  'ameicuadn',
#  'axmeiqan',
#  'amsicafn',
#  'awmesican',
#  'aymyeican',
#  'amhteican',
#  'ameidvn',
#  'amepcas',
#  'ameipcaa',
#  'ameliecan',
#  'pmeicavn',
#  'amebjcan',
#  'zameicqan',
#  'amepmican',
#  'ameikjn',
#  'qmteican',
#  'imeicakn',
#  'lmeigan',
#  'acmeicah',
#  'tameicnn',
#  'zmescan',
#  'amsictn',
#  'amzlican',
#  'apeicnn',
#  'ameiuad',
#  'ldameican',
#  'ameicayp',
#  'qmvican',
#  'amyicad',
#  'amzicran',
#  'eameoican',
#  'vmeimcan',
#  'areibcan',
#  'amekicxan',
#  'amseicar',
#  'amesiccn',
#  'afjmeican',
#  'vameycan',
#  'cameiscan',
#  'amevicajn',
#  'amebecan',
#  'afmweican',
#  'amevicawn',
#  'aheicaan',
#  'fametican',
#  'eaveican',
#  'emeicln',
#  'aumeicaf',
#  'amebhcan',
#  'dameicasn',
#  'amuekcan',
#  'amepcan',
#  'aameicean',
#  'emeicahn',
#  'ameicajy',
#  'amerian',
#  'ymxeican',
#  'damreican',
#  'damwican',
#  'vmetcan',
#  'kmweican',
#  'oameicran',
#  'ameicwbn',
#  'kadeican',
#  'ameickad',
#  'ameficxan',
#  'ameimcsn',
#  'nmeifcan',
#  'akekican',
#  'admeilcan',
#  'amniman',
#  'uameiscan',
#  'ameliwan',
#  'xmelcan',
#  'aameicaen',
#  'qmeicmn',
#  'umeichn',
#  'amkicadn',
#  'bamedcan',
#  'ameizrn',
#  'amjenican',
#  'awrmeican',
#  'sveican',
#  'azeiczn',
#  'hamxican',
#  'afmeian',
#  'amhicgn',
#  'ameggcan',
#  'afmeicaxn',
#  'amaicacn',
#  'amxedcan',
#  'ameniecan',
#  'ameitvan',
#  'aeicae',
#  'cameiaan',
#  'amedqcan',
#  'amgeicfn',
#  'amewigan',
#  'bampican',
#  'amfeixcan',
#  'amhlican',
#  'xmeiqan',
#  'tamjican',
#  'amejicaj',
#  'ameixcean',
#  'akeicyn',
#  'ammicaln',
#  'kmeicaun',
#  'oamencan',
#  'ameitcn',
#  'hmeicaqn',
#  'amyeicln',
#  'ameiwcap',
#  'amyeickan',
#  'amueeican',
#  'rameicdan',
#  'agsican',
#  'ameijocan',
#  'amevicbn',
#  'ameicvwan',
#  'omuican',
#  'ameincain',
#  'ameictaz',
#  'wmeiccn',
#  'cameiran',
#  'baameican',
#  'ameicuak',
#  'qarmeican',
#  'amefnican',
#  'asmeicuan',
#  'amixan',
#  'aameucan',
#  'amyicao',
#  'amecicqan',
#  'amkewican',
#  'ameicja',
#  'amseicaan',
#  'eambican',
#  'armeaican',
#  'hmceican',
#  'amveilcan',
#  'amuicac',
#  'ameiplcan',
#  'amuixcan',
#  'emeicakn',
#  'amekcatn',
#  'amoifcan',
#  'ameihtan',
#  'tmeidcan',
#  'ameicdaw',
#  'amefician',
#  'amljican',
#  'aneocan',
#  'amcicrn',
#  'adeicyn',
#  'anmeicatn',
#  'amebqan',
#  'ahmeicnan',
#  'lmeicann',
#  'jamkican',
#  'atmeicln',
#  'ameicagrn',
#  'aameiaan',
#  'bveican',
#  'amkeicaw',
#  'amqiican',
#  'ajmwican',
#  'dameickan',
#  'ameicocn',
#  'ameiczfn',
#  'ammeigan',
#  'ameizcvn',
#  'ameicas',
#  'avleican',
#  'bmecan',
#  'dmeicyn',
#  'ameiuckn',
#  'amehisan',
#  'alpmeican',
#  'aueicin',
#  'ameiwcaj',
#  'ameicaqz',
#  'xmeicxan',
#  'umefcan',
#  'awdican',
#  'amjaeican',
#  'amqicgan',
#  'ameizaln',
#  'azmeicln',
#  'ameircaen',
#  'ameihwcan',
#  'amgeical',
#  'aqezican',
#  'ameitah',
#  'wmeicaxn',
#  'attmeican',
#  'ameiecjn',
#  'oameicean',
#  'bmxican',
#  'amqzican',
#  'kmeicamn',
#  'emwican',
#  'ameicsadn',
#  'amqidcan',
#  'vadmeican',
#  'azmebcan',
#  'ameicayzn',
#  'amefiyan',
#  'aemeircan',
#  'yameiucan',
#  'iameioan',
#  'cmeiian',
#  'ameiclaon',
#  'axumeican',
#  'ampivcan',
#  'ameiqctan',
#  'oamveican',
#  'ameifhcan',
#  'bbeican',
#  'amegcyn',
#  'lmeiyan',
#  'kamleican',
#  'samaican',
#  'ameimahn',
#  'aqeicaun',
#  'ameicalf',
#  'mxameican',
#  'ameiecajn',
#  'amepicak',
#  'zameicjan',
#  'amelxan',
#  'ameiqcain',
#  'famxican',
#  'qamyeican',
#  'akmeilcan',
#  'aeepican',
#  'amoeizcan',
#  'akmeicagn',
#  'ameicuxn',
#  'amezcxan',
#  'matmeican',
#  'aeeiecan',
#  'eamoican',
#  'axmeisan',
#  'ymkeican',
#  'afsican',
#  'ameicrasn',
#  'azeidan',
#  'wameiclan',
#  'almeickan',
#  'amexcagn',
#  'amnemcan',
#  'namescan',
#  'aheqcan',
#  'amescaen',
#  'ameycun',
#  'amepcasn',
#  'xameicmn',
#  'amejcon',
#  'abmeeican',
#  'avmeicar',
#  'amkeicamn',
#  'amboeican',
#  'ameicusn',
#  'amoiclan',
#  'gmeicpn',
#  'aumeinan',
#  'amaicdan',
#  'amifan',
#  'amyeicai',
#  'amesifan',
#  'almeicawn',
#  'jameicln',
#  'ameidaq',
#  'admehican',
#  'ameilqn',
#  'adeictan',
#  'amicacn',
#  'gmehcan',
#  'abeicax',
#  'ameihean',
#  'ameiemn',
#  'vmeicay',
#  'fameicax',
#  'aieicon',
#  'ameincin',
#  'bameicwn',
#  'amefcpan',
#  'asrmeican',
#  'cmefican',
#  'amexman',
#  'ameieean',
#  'yateican',
#  'ameimcen',
#  'ameoqcan',
#  'amuicajn',
#  'amjeisan',
#  'tmnican',
#  'amjicqn',
#  'dameicyan',
#  'ewameican',
#  'amemcatn',
#  'imeicbn',
#  'ameicialn',
#  'wameicao',
#  'aimemcan',
#  'cmeicazn',
#  'aceicat',
#  'ambicadn',
#  'amwixcan',
#  'amhicaa',
#  'aeeicaln',
#  'ammicazn',
#  'aameicann',
#  'cmeiman',
#  'ameiocaen',
#  'uameicnan',
#  'cameicasn',
#  'sameicadn',
#  'amleical',
#  'nameiczn',
#  'amxpeican',
#  'qameicgn',
#  'ameihcavn',
#  'vneican',
#  'ameiwcaen',
#  'amepicahn',
#  'ameicanan',
#  'asmeicwn',
#  'ameoacan',
#  'ameoickn',
#  'jmeicdan',
#  'nmceican',
#  'cmeicawn',
#  'gamxican',
#  'cameicabn',
#  'amreicon',
#  'almeicadn',
#  'uameidan',
#  'ameidag',
#  'amedcah',
#  'ameicjay',
#  'ameakan',
#  'amecafn',
#  'dameiczan',
#  'ahmexican',
#  'ayzican',
#  'cmeian',
#  'rameaican',
#  'bgameican',
#  'areixcan',
#  'ameicaio',
#  'hamoican',
#  'afmkican',
#  'ameipcakn',
#  'aqeifcan',
#  'ameicasj',
#  'zameqican',
#  'amxeyican',
#  'ameiuaon',
#  'amexicat',
#  'amnucan',
#  'akeicnn',
#  'azeicajn',
#  'aubeican',
#  'aambican',
#  'nameicap',
#  'ameiycar',
#  'lmeicn',
#  'pmiican',
#  'ameictxan',
#  'abeicjn',
#  'aieiccan',
#  'anmeician',
#  'hwmeican',
#  'ameikaan',
#  'iakeican',
#  'mameicpn',
#  'xameicaln',
#  'damewcan',
#  'apmeigan',
#  'amlicaln',
#  'oameicman',
#  'fameigcan',
#  'ameicdav',
#  'qrameican',
#  'pmeicab',
#  'umeicaen',
#  'saheican',
#  'almeicaxn',
#  'amzeicsn',
#  'ajiican',
#  'aweiocan',
#  'akmeicwn',
#  'amepicyn',
#  'nameical',
#  'gayeican',
#  'uameicuan',
#  'aemeichn',
#  'amheicjn',
#  'awmeiican',
#  'adeiacan',
#  'amkehcan',
#  'meimcan',
#  'omweican',
#  'iameicnn',
#  'aeenican',
#  'damfican',
#  'abzeican',
#  'avmeicaj',
#  'ioameican',
#  'ameicbl',
#  'amefcran',
#  'americann',
#  'amehicab',
#  'amimeican',
#  'amfceican',
#  'amxeiczn',
#  'atmeixan',
#  'almeicarn',
#  'ameioadn',
#  'ameivcakn',
#  'rameiczn',
#  'amegicaj',
#  'ameicsas',
#  'ambeacan',
#  'mescan',
#  'amediman',
#  'cmeicad',
#  'aimedcan',
#  'gameicaan',
#  'fmefican',
#  'haymeican',
#  'amneicaq',
#  'amnzcan',
#  'amciran',
#  'ameisbcan',
#  'amezjcan',
#  'lamnican',
#  'bymeican',
#  'amceicaan',
#  'ambekcan',
#  'amticacn',
#  'amkeiscan',
#  'xabeican',
#  'ameizawn',
#  'agedican',
#  'gmeicfan',
#  ...}

# %%
def get_corrections(word, vocab,prob, n=2):
    
    '''
    1. use short circuit to get all possible suggestions from a)vocab, b)1 edit, c)2 edit, d) word
    2. create word freq from vocab using get_freq funct and get_prob
    3. get top n words with probs
    
    input:
    word: the Possibly incorrect word
    vocab: vocab dict
    prob: word prob
    n: top n suggestions to consider
    
    output:
    dict of top n suggested word with their probs
    '''
    
    suggestions = []
    n_best = {}
    
    suggestions = list(one_edit(word).intersection(vocab) or two_edit(word).intersection(vocab) or (word in vocab and word) or word)
    print(suggestions) ##PROBLEM TO FIX WITH SINGLE WORD OUTPUT
    
    sugg_prob = {i:prob[i] for i in suggestions}

    #sort dict and pick top n
    sorted_prob = sorted(sugg_prob.items(), key=lambda x: x[1], reverse=True)[:n]
    
    
    return sorted_prob

# %%
get_corrections('kiama',vocab,prob, n=2)
# Out:
# ['nirma', 'karma']
# [('nirma', 0.023529411764705882), ('karma', 0.011764705882352941)]

# %% [markdown]
# ### Minimum Edit Distance using Dynamic Programming

# %% [markdown]
# 1. Given a String Source[0,i] and a String Target[0,j], we will compute all possible combinations of substrings [i,j] and their Minimum Edit Distance.
# 2. We will maintain the previously computed substrings and use them to calculate the larger substrings
# 3. We need to maintain a matrix D.
# 4. Rows = characters of Source string + (1 extra blank), Col = characters of Target string + (extra blank)
# 5. We begin with "Initialization"
#     a) D[0,0] = 0
#     b) Compute edit distances for all elements of 1st row and 1st col
#         D[i,0] = D[i-1,0] + del_cost(source[i])
#         D[0,j] = D[0,j-1] + ins_cost(source[j])
# 6. Now compute D[i,j]
#         min{ D[i-1,j] + del_cost(source[i])
#              D[i,j-1] + ins_cost(target[j])
#              D[i-1,j-1] + {rep_cost, i != j
#                            0, i = j}
#                                    }

# %%
# minimum amount of edits required given a source and a target string

def minimum_edit_distance(source, target, del_cost=1, ins_cost=1,rep_cost=2):
    
    """
    1. Initialize: 
        D of size [i+1,j+1]
        [0,0]=0
        D[i,0]=D[i-1,0]+del_cost
        D[0,j]=D[0,j-1]+ins_cost
    
    2. Loop through i,j:
     min{ D[i-1,j] + del_cost(source[i])
          D[i,j-1] + ins_cost(target[j])
          D[i-1,j-1] + {rep_cost, i != j
                    0, i = j}
                            }
    
    3. mini edit distance will be the last cell [i,j] of matrix, i=j
    
    4. Make the matrix more readable, by converting to df and adding indexes
    
    Input: 
    Source string
    Target string
    Delete_cost, insert_cost, replace_cost
    
    Output:
    Dataframe D, Minimum edit distance
    """
    #create matrix
    
    i_len = len(source)
    j_len = len(target)
    
    idx = ['#']+list(source)
    jdx = ['#']+list(target)
    
    D = np.zeros((i_len+1,j_len+1),int)
    
    #initialize the matrix
    D[0,0] = 0
    
    for i in range(1,i_len+1):
        D[i,0] = D[i-1,0]+del_cost

    for j in range(1,j_len+1):
        D[0,j] = D[0,j-1]+ins_cost
        
    #fill each cell [i,j]
    for i in range(1,i_len+1):
        for j in range(1,j_len+1):
            
            #initialize rep_cost
            rep=rep_cost
            
            if source[i-1]==target[j-1]:
                rep=0
            
            D[i,j] = min(D[i-1,j]+del_cost, D[i,j-1]+ins_cost, D[i-1,j-1]+rep)
                
                
    med = D[i_len,j_len]
    
    D = pd.DataFrame(D, index=idx, columns=jdx)
    print(f'minimum edit distance is {med}')
    return D, med

# %%
minimum_edit_distance('ant','want')
# Out:
# minimum edit distance is 1
# (   #  w  a  n  t
#  #  0  1  2  3  4
#  a  1  2  1  2  3
#  n  2  3  2  1  2
#  t  3  4  3  2  1, 1)
