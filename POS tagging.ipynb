# %%
"""
1. read txt file
2. 
"""
# Out:
# '\n\n'

# %%
import string
from collections import defaultdict

# %%
# read POS tagged file

with open('./data/WSJ_02-21.pos') as f:
    file = f.readlines()

# %%
file[0]
# Out:
# 'In\tIN\n'

# %%
for i in range(5):
    print(f'{i}: {file[i]}')
# Out:
# 0: In	IN
#
# 1: an	DT
#
# 2: Oct.	NNP
#
# 3: 19	CD
#
# 4: review	NN

# %%
#create vocab
#collect the words

words = [i.split('\t')[0] for i in file]

# %%
words
# Out:
# ['In',
#  'an',
#  'Oct.',
#  '19',
#  'review',
#  'of',
#  '``',
#  'The',
#  'Misanthrope',
#  "''",
#  'at',
#  'Chicago',
#  "'s",
#  'Goodman',
#  'Theatre',
#  '(',
#  '``',
#  'Revitalized',
#  'Classics',
#  'Take',
#  'the',
#  'Stage',
#  'in',
#  'Windy',
#  'City',
#  ',',
#  "''",
#  'Leisure',
#  '&',
#  'Arts',
#  ')',
#  ',',
#  'the',
#  'role',
#  'of',
#  'Celimene',
#  ',',
#  'played',
#  'by',
#  'Kim',
#  'Cattrall',
#  ',',
#  'was',
#  'mistakenly',
#  'attributed',
#  'to',
#  'Christina',
#  'Haag',
#  '.',
#  '\n',
#  'Ms.',
#  'Haag',
#  'plays',
#  'Elianti',
#  '.',
#  '\n',
#  'Rolls-Royce',
#  'Motor',
#  'Cars',
#  'Inc.',
#  'said',
#  'it',
#  'expects',
#  'its',
#  'U.S.',
#  'sales',
#  'to',
#  'remain',
#  'steady',
#  'at',
#  'about',
#  '1,200',
#  'cars',
#  'in',
#  '1990',
#  '.',
#  '\n',
#  'The',
#  'luxury',
#  'auto',
#  'maker',
#  'last',
#  'year',
#  'sold',
#  '1,214',
#  'cars',
#  'in',
#  'the',
#  'U.S.',
#  '\n',
# ...
